# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# ## 1 A simple plot

# %% [markdown]
# ### 1.1 Let’s look at some code.

# %%
from matplotlib import pyplot as plt

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

plt.plot(x, y_1, color='blue', linestyle='dotted', label='Y values')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=0.30)
plt.legend(loc='lower right')
plt.show()

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

plt.plot(x, y_1, color='magenta', linestyle='dashed', linewidth=2)

# %% [markdown]
# ### 1.2 Adding another plot

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

plt.plot(x, y_1, c='orange', ls='dashed', lw=2, label = 'Y1 values')
plt.plot(x,y_2, c='indigo', ls='dashed', lw=2, label = 'Y2 values')

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=0.30)
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.3 Yet another plot but with error bars

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]
y_3 = [0, 4, 8, 12, 16, 20, 24]
x_error, y_error = 0.1, 0.75

plt.plot(x, y_1, c='#f6bd60', ls='dashed', lw=2, label = 'Y1 values')
plt.plot(x,y_2, c='#84a59d', ls='dashed', lw=2, label = 'Y2 values')
plt.errorbar(x, y_3, xerr = x_error, yerr = y_error, ls='dashed', lw=2,
             color = "#f5cac3", label = "Y3 with errors")

plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.legend(loc='upper left')
plt.grid(alpha = 0.5, color = '#fec89a', linestyle = 'dotted')
plt.show()

# %% [markdown]
# ### 1.4 Experiment, Experiment, Experiment

# %% [markdown]
# ### 1.5 Better with NumPy

# %%
import numpy as np

# %%
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

np_x = np.array(x)
np_y_1 = np.array(y_1)
np_y_2 = np.array(y_2)

plt.plot(np_x, np_y_1, color='#c1121f', linestyle='dashed', label='Y values')
plt.plot(np_x, np_y_2, color='#669bbc', linestyle = 'dashed', label='Y2 values')
plt.show()

# %% [markdown]
# ### 1.6 Adding mathematical functions

# %%
x = np.array([0,1,2,3,4,5,6])
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='#9c89b8', linestyle='dashed', label='x^2')
plt.plot(x, sin_x, color='#f0a6ca', label='sin(x)')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 1.7 We need another axis!

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='#9c89b8', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

plt.twinx()
plt.plot(x, sin_x, color='#f0a6ca', label= 'sin(x)')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# ### 1.8 Saving to disc

# %%
x = np.linspace(0, 6, 100)
x2 = x**2
sin_x = np.sin(x)

plt.plot(x, x2, color='#669bbc', linestyle='dashed', label='x^2')
plt.legend(loc='lower left')

plt.twinx()
plt.plot(x, sin_x, color='#c1121f', label='sin(x)')
plt.legend(loc='lower right')

plt.savefig('simple-plot.png', dpi=150)

# %% [markdown]
# ## 2 A real example: Global Warming

# %% [markdown]
# ### 2.1 Plotting data from files

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8,8])
# Out:
# (-8.0, 8.0)

# %%
data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

# %%
plt.style.use('fivethirtyeight')

data = np.loadtxt('Complete_TAVG_daily.txt', skiprows=24)
date = data[:, 0]
anomaly = data[:, -1]

plt.plot(date, anomaly, alpha=.5)
plt.ylim([-8, 8])
plt.hlines(0, date[0], date[-1], linestyle='--', colors='grey')

plt.xlabel('Year')
plt.ylabel('Temperature Anomaly')
plt.title('Temperature anomaly \n(Relative to average from Jan 1951 - Dec 1980)')
plt.grid(alpha=0.30)

# %%
plt.style.use('default')

# %% [markdown]
# ### 2.2 xkcd!

# %%
# Your code here

# %% [markdown]
# ## Exercise 1 :  Fill in the blanks

# %%
x = [0, 1, 2, 3, 4, 5]
y = [0, 4, 8, 12, 16, 20]
y_err = [0.0, 0.5, 1.0, 1.5, 2.0, 2.5]
x_err = .25

plt.errorbar(x, y, xerr= x_err, yerr= y_err,
             color= 'maroon', linestyle='dashed',
             marker='o', markerfacecolor= 'yellow',
             ecolor='black',capsize=5,
             label='Y values with errors')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower right')
plt.savefig('ex1 plot.png', dpi=150)                  # Hide
plt.show(block=False)

# %% [markdown]
# ## Exercise 2 :  A simple mathematical plot
